-- %%
SET XACT_ABORT ON; BEGIN TRAN;

DECLARE @n INT = (SELECT ISNULL(MAX(TA_No),0)+1 FROM F_TAXE);

IF NOT EXISTS (SELECT 1 FROM F_TAXE WHERE TA_Code='C18')
BEGIN
  INSERT INTO F_TAXE (TA_No,TA_Code,TA_Intitule,TA_Taux,TA_TTaux,TA_Type,TA_Sens,TA_Provenance,TA_Assujet,TA_GrilleBase,TA_GrilleTaxe,CG_Num,TA_NP,TA_Regroup,TA_EdiCode)
  SELECT @n,'C18','TVA collectée à 18%',18.0,0,TA_Type,TA_Sens,TA_Provenance,TA_Assujet,TA_GrilleBase,TA_GrilleTaxe,CG_Num,TA_NP,TA_Regroup,TA_EdiCode FROM F_TAXE WHERE TA_Code='C20';
  SET @n+=1;
END
IF NOT EXISTS (SELECT 1 FROM F_TAXE WHERE TA_Code='C05')
BEGIN
  INSERT INTO F_TAXE (TA_No,TA_Code,TA_Intitule,TA_Taux,TA_TTaux,TA_Type,TA_Sens,TA_Provenance,TA_Assujet,TA_GrilleBase,TA_GrilleTaxe,CG_Num,TA_NP,TA_Regroup,TA_EdiCode)
  SELECT @n,'C05','TVA collectée à 5%',5.0,0,TA_Type,TA_Sens,TA_Provenance,TA_Assujet,TA_GrilleBase,TA_GrilleTaxe,CG_Num,TA_NP,TA_Regroup,TA_EdiCode FROM F_TAXE WHERE TA_Code='C20';
  SET @n+=1;
END
IF NOT EXISTS (SELECT 1 FROM F_TAXE WHERE TA_Code='D18')
BEGIN
  INSERT INTO F_TAXE (TA_No,TA_Code,TA_Intitule,TA_Taux,TA_TTaux,TA_Type,TA_Sens,TA_Provenance,TA_Assujet,TA_GrilleBase,TA_GrilleTaxe,CG_Num,TA_NP,TA_Regroup,TA_EdiCode)
  SELECT @n,'D18','TVA déductible à 18%',18.0,0,TA_Type,TA_Sens,TA_Provenance,TA_Assujet,TA_GrilleBase,TA_GrilleTaxe,CG_Num,TA_NP,TA_Regroup,TA_EdiCode FROM F_TAXE WHERE TA_Code='D20';
  SET @n+=1;
END
IF NOT EXISTS (SELECT 1 FROM F_TAXE WHERE TA_Code='D05')
BEGIN
  INSERT INTO F_TAXE (TA_No,TA_Code,TA_Intitule,TA_Taux,TA_TTaux,TA_Type,TA_Sens,TA_Provenance,TA_Assujet,TA_GrilleBase,TA_GrilleTaxe,CG_Num,TA_NP,TA_Regroup,TA_EdiCode)
  SELECT @n,'D05','TVA déductible à 5%',5.0,0,TA_Type,TA_Sens,TA_Provenance,TA_Assujet,TA_GrilleBase,TA_GrilleTaxe,CG_Num,TA_NP,TA_Regroup,TA_EdiCode FROM F_TAXE WHERE TA_Code='D20';
  SET @n+=1;
END

SELECT TA_No,TA_Code,TA_Taux,TA_Intitule FROM F_TAXE WHERE TA_Code IN ('C18','C05','D18','D05') ORDER BY TA_Code; -- doit retourner 4 lignes
COMMIT;
-- Out:
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (1 row affected)
-- (4 rows affected)
--
-- TA_No | TA_Code | TA_Taux   | TA_Intitule
-- ------+---------+-----------+---------------------
-- 23    | C05     | 5.000000  | TVA collectée à 5%
-- 22    | C18     | 18.000000 | TVA collectée à 18%
-- 25    | D05     | 5.000000  | TVA déductible à 5%
-- 24    | D18     | 18.000000 | TVA déductible à 18%
-- (4 rows)
--
-- Total execution time: 00:00:01.423
